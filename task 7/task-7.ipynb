# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\sonu kumar\Downloads\Data_m.csv')

# %%
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
df.describe(include='all').T
# Out:
#                          count unique       top freq       mean  \
# Mthly_HH_Income           50.0    NaN       NaN  NaN    41558.0
# Mthly_HH_Expense          50.0    NaN       NaN  NaN    18818.0
# No_of_Fly_Members         50.0    NaN       NaN  NaN       4.06
# Emi_or_Rent_Amt           50.0    NaN       NaN  NaN     3060.0
# Annual_HH_Income          50.0    NaN       NaN  NaN  490019.04
# Highest_Qualified_Member    50      5  Graduate   19        NaN
# No_of_Earning_Members     50.0    NaN       NaN  NaN       1.46
#
#                                     std      min       25%       50%  \
# Mthly_HH_Income            26097.908979   5000.0   23550.0   35000.0
# Mthly_HH_Expense           12090.216824   2000.0   10000.0   15500.0
# No_of_Fly_Members              1.517382      1.0       3.0       4.0
# Emi_or_Rent_Amt             6241.434948      0.0       0.0       0.0
# Annual_HH_Income          320135.792123  64200.0  258750.0  447420.0
# ...

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
sns.distplot(df['Mthly_HH_Income']);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### from above we can see that the distubtion is normly. normly becuse in btween points are many and at lower end less points are there and same in higer end.

# %%
sns.distplot(df['Mthly_HH_Expense']);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##from above we can see that the distubtion is normly. normly becuse in btween points are many and at lower end less points are there and same in higer end.

# %%
sns.distplot(df['No_of_Fly_Members']);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### from above we can see that the distubtion is normly. normly becuse in btween points are many and at lower end less points are there and same in higer end.

# %%
sns.distplot(df['Emi_or_Rent_Amt']);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### from graph we can see that num of Emi_or_Rent_Amt is personal home

# %%
sns.distplot(df['Annual_HH_Income']);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### from above we can see that the distubtion is normly. normly becuse in btween points are many and at lower end less points are there and same in higer end.

# %%
sns.countplot(df.Highest_Qualified_Member);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### graduate people more than others

# %%
sns.countplot(df.No_of_Earning_Members);
# Out:
# C:\Users\sonu kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### most of the houses is only one person is earning members

# %%
sns.barplot(x='Mthly_HH_Income',y='Highest_Qualified_Member',data=df);

# %% [markdown]
# ### post graduate is having more monthly income

# %%
sns.barplot(x='Annual_HH_Income',y='Highest_Qualified_Member',data=df);

# %% [markdown]
# ### post graduate is having more anual income

# %%
sns.barplot(x='Mthly_HH_Expense',y='Highest_Qualified_Member',data=df);

# %% [markdown]
# ### professional member having more monthly_HH_Expense

# %%
sns.barplot(y='Mthly_HH_Expense',x='No_of_Earning_Members',data=df);

# %% [markdown]
# ### if there are 3_no of earning members,than monthly expense are more

# %%
sns.barplot(y='Mthly_HH_Income',x='No_of_Earning_Members',data=df);

# %% [markdown]
# ### if number of earning member is 3 than,monthly income is more

# %%
sns.barplot(y='Mthly_HH_Expense',x='No_of_Fly_Members',data=df);

# %% [markdown]
# ### as family members are increasing than also montly expense is increasing

# %%
sns.barplot(x='No_of_Fly_Members',y='Emi_or_Rent_Amt',data=df);

# %% [markdown]
# ### if number of emp is 3 than emi or rent is increasing

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True);

# %%
sns.pairplot(data = df);

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
plt.figure(figsize=(50, 50))

sns.catplot(x='Mthly_HH_Expense', y="Mthly_HH_Income", kind="box", data=df)
plt.xticks(rotation=90);
